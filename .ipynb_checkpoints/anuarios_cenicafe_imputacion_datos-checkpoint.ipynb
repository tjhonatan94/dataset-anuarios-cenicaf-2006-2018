# %%
import pandas as pd

# %%
data= pd.read_csv('anu2006_end.csv')
data.head()
# Out:
#   Estacion:       El Trapiche Dpto: Antioquia          Latitud  :       5°  \
# 0      Año:              2006   Mpio: Bolívar           Longitud:      76°
# 1       NaN               NaN        Altitud:                1277        m
# 2       NaN  Temperatura (°C)            Hum.  Precipitación (mm)   Brillo
# 3     Enero    Mín. Máx. Med.         Rel.(%)     Dia Noche Total  Sol.(h)
# 4         1    16.6 28.4 20.4            74.7         0.0 0.0 0.0      4.3
#
#    48'    N
# 0   1'    W
# 1  NaN  NaN
# 2  NaN  NaN
# 3  NaN  NaN
# 4  NaN  NaN

# %%
df = pd.DataFrame(data)
df
# Out:
#        Estacion:       El Trapiche Dpto: Antioquia          Latitud  :  \
# 0           Año:              2006   Mpio: Bolívar           Longitud:
# 1            NaN               NaN        Altitud:                1277
# 2            NaN  Temperatura (°C)            Hum.  Precipitación (mm)
# 3          Enero    Mín. Máx. Med.         Rel.(%)     Dia Noche Total
# 4              1    16.6 28.4 20.4            74.7         0.0 0.0 0.0
# ...          ...               ...             ...                 ...
# 23277         29    16.4 27.8 21.7            71.3         0.0 0.0 0.0
# 23278         30    17.0 25.8 21.4            75.3         0.0 0.0 0.0
# 23279         31    16.2 27.2 21.3            72.0         0.0 0.0 0.0
# 23280     Total:               NaN             NaN     63.3 67.0 130.3
# 23281  Promedio:    16.5 25.0 20.2            77.2                 NaN
#
#             5°  48'    N
# 0          76°   1'    W
# 1            m  NaN  NaN
# 2       Brillo  NaN  NaN
# ...

# %%
new_data = data.dropna(axis = 0, how ='any') 
new_data
# Out:
#        Estacion:           El Trapiche  Dpto: Antioquia  Latitud  :   5°  48'  \
# 0           Año:                  2006    Mpio: Bolívar   Longitud:  76°   1'
# 422    Estacion:               Cocorná  Dpto: Antioquia  Latitud  :   6°   4'
# 423         Año:                  2006    Mpio: Cocorná   Longitud:  75°  11'
# 845    Estacion:       Miguel Valencia  Dpto: Antioquia  Latitud  :   5°  36'
# 846         Año:                  2006     Mpio: Jardín   Longitud:  75°  51'
# ...          ...                   ...              ...         ...  ...  ...
# 22014       Año:                  2006   Mpio: Restrepo   Longitud:  76°  32'
# 22436  Estacion:             La Sirena      Dpto: Valle  Latitud  :   4°  17'
# 22437       Año:                  2006    Mpio: Sevilla   Longitud:  75°  54'
# 22859  Estacion:   Manuel M. Mallarino      Dpto: Valle  Latitud  :   4°  13'
# 22860       Año:                  2006   Mpio: Trujillo   Longitud:  76°  19'
#
#        N
# 0      W
# 422    N
# ...

# %%
print("Old data frame length:", len(data)) 
print("New data frame length:", len(new_data))  
print("Number of rows with at least 1 NA value: ", (len(data)-len(new_data)))
# Out:
# Old data frame length: 23282
# New data frame length: 121
# Number of rows with at least 1 NA value:  23161

# %%
estaciones=df[['estacion']]

estaciones
# Out:
#                    estacion
# 0               El Trapiche
# 1                   Cocorná
# 2           Miguel Valencia
# 3             Virgen de Oro
# 4             La Cristalina
# ...                     ...
# 232668              El Rubí
# 232669         Arturo Gómez
# 232670         07 Fernández
# 232671            La Sirena
# 232672  Manuel M. Mallarino
#
# [232673 rows x 1 columns]

# %%
filtrar=data[(data['estacion'] == 'Tricontinental')]
filtrar
# Out:
#       Fecha (Dia/Mes/Año)        estacion departamento municipio  \
# 3492            11/3/2006  Tricontinental       Tolima    Fresno
# 3543            12/3/2006  Tricontinental       Tolima    Fresno
# 3594            13/3/2006  Tricontinental       Tolima    Fresno
# 3645            14/3/2006  Tricontinental       Tolima    Fresno
# 3696            15/3/2006  Tricontinental       Tolima    Fresno
# ...                   ...             ...          ...       ...
# 90337           16/9/2010  Tricontinental       Tolima    Fresno
# 90390           17/9/2010  Tricontinental       Tolima    Fresno
# 90443           18/9/2010  Tricontinental       Tolima    Fresno
# 90496           19/9/2010  Tricontinental       Tolima    Fresno
# 90549           20/9/2010  Tricontinental       Tolima    Fresno
#
#        tempe_min (°C)  temp_max(°C)  temp_media(°C)  humedad relativa(%)  \
# 3492             18.0          26.9            22.1                 75.3
# ...

# %%
filtrar.sort_index(axis=0, ascending =True)
# Out:
#       Fecha (Dia/Mes/Año)        estacion departamento municipio  \
# 3492            11/3/2006  Tricontinental       Tolima    Fresno
# 3543            12/3/2006  Tricontinental       Tolima    Fresno
# 3594            13/3/2006  Tricontinental       Tolima    Fresno
# 3645            14/3/2006  Tricontinental       Tolima    Fresno
# 3696            15/3/2006  Tricontinental       Tolima    Fresno
# ...                   ...             ...          ...       ...
# 90337           16/9/2010  Tricontinental       Tolima    Fresno
# 90390           17/9/2010  Tricontinental       Tolima    Fresno
# 90443           18/9/2010  Tricontinental       Tolima    Fresno
# 90496           19/9/2010  Tricontinental       Tolima    Fresno
# 90549           20/9/2010  Tricontinental       Tolima    Fresno
#
#        tempe_min (°C)  temp_max(°C)  temp_media(°C)  humedad relativa(%)  \
# 3492             18.0          26.9            22.1                 75.3
# ...
