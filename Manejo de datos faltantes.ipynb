# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.colors import ListedColormap
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
data= pd.read_csv('fileOut.csv')
data.head()
# Out:
#           Fecha      Estacion Departamento Municipio  Temperatura_min  \
# 0  1/Enero/2006   El Trapiche    Antioquia   Bolívar             16.6
# 1  2/Enero/2006   El Trapiche    Antioquia   Bolívar             17.6
# 2  3/Enero/2006   El Trapiche    Antioquia   Bolívar             17.4
# 3  4/Enero/2006   El Trapiche    Antioquia   Bolívar             15.7
# 4  5/Enero/2006   El Trapiche    Antioquia   Bolívar             17.2
#
#    Temperatura_max  Temperatura_med  Humedad_rel  Precipitacion_dia  \
# 0             28.4             20.4         74.7                0.0
# 1             28.0             21.0         74.3                0.0
# 2             26.5             20.4         77.3                0.0
# 3             27.6             20.7         72.0                0.0
# 4             25.2             19.2         86.0                0.3
#
#    Precipitacion_noche  Precipitacion_total  Brillo_solar Longitud Latitud  \
# ...

# %%
data.notnull().apply(pd.Series.value_counts)
# Out:
#           Fecha  Estacion  Departamento  Municipio  Temperatura_min  \
# False       NaN       NaN           NaN        NaN             3430
# True   489622.0  489622.0      489622.0   489622.0           486192
#
#        Temperatura_max  Temperatura_med  Humedad_rel  Precipitacion_dia  \
# False             3430             3430         3922                734
# True            486192           486192       485700             488888
#
#        Precipitacion_noche  Precipitacion_total  Brillo_solar  Longitud  \
# False                  734                  734         20296       NaN
# True                488888               488888        469326  489622.0
#
#         Latitud   Altitud
# False       NaN       NaN
# True   489622.0  489622.0

# %%
new_data_fill = data.fillna(method="ffill")
new_data_fill
# Out:
#                     Fecha              Estacion Departamento Municipio  \
# 0            1/Enero/2006           El Trapiche    Antioquia   Bolívar
# 1            2/Enero/2006           El Trapiche    Antioquia   Bolívar
# 2            3/Enero/2006           El Trapiche    Antioquia   Bolívar
# 3            4/Enero/2006           El Trapiche    Antioquia   Bolívar
# 4            5/Enero/2006           El Trapiche    Antioquia   Bolívar
# ...                   ...                   ...          ...       ...
# 489617  27/Diciembre/2018   Manuel M. Mallarino        Valle  Trujillo
# 489618  28/Diciembre/2018   Manuel M. Mallarino        Valle  Trujillo
# 489619  29/Diciembre/2018   Manuel M. Mallarino        Valle  Trujillo
# 489620  30/Diciembre/2018   Manuel M. Mallarino        Valle  Trujillo
# 489621  31/Diciembre/2018   Manuel M. Mallarino        Valle  Trujillo
#
#         Temperatura_min  Temperatura_max  Temperatura_med  Humedad_rel  \
# ...

# %%
new_data_fill.notnull().apply(pd.Series.value_counts)
# Out:
#        Fecha  Estacion  Departamento  Municipio  Temperatura_min  \
# True  489622    489622        489622     489622           489622
#
#       Temperatura_max  Temperatura_med  Humedad_rel  Precipitacion_dia  \
# True           489622           489622       489622             489622
#
#       Precipitacion_noche  Precipitacion_total  Brillo_solar  Longitud  \
# True               489622               489622        489622    489622
#
#       Latitud  Altitud
# True   489622   489622

# %%
new_data_inter = data.interpolate()

# %%
new_data_inter.notnull().apply(pd.Series.value_counts)
# Out:
#        Fecha  Estacion  Departamento  Municipio  Temperatura_min  \
# True  489622    489622        489622     489622           489622
#
#       Temperatura_max  Temperatura_med  Humedad_rel  Precipitacion_dia  \
# True           489622           489622       489622             489622
#
#       Precipitacion_noche  Precipitacion_total  Brillo_solar  Longitud  \
# True               489622               489622        489622    489622
#
#       Latitud  Altitud
# True   489622   489622

# %%
df = pd.DataFrame(new_data_inter)
df.to_csv('Anuarios_completo_interp.csv')

# %%
new_data_inter = data["Temperatura_min"]
new_data_inter.head()
# Out:
# 0    16.6
# 1    17.6
# 2    17.4
# 3    15.7
# 4    17.2
# Name: Temperatura_min, dtype: float64

# %%
# Out:
#                     Fecha              Estacion Departamento Municipio  \
# 0            1/Enero/2006           El Trapiche    Antioquia   Bolívar
# 1            2/Enero/2006           El Trapiche    Antioquia   Bolívar
# 2            3/Enero/2006           El Trapiche    Antioquia   Bolívar
# 3            4/Enero/2006           El Trapiche    Antioquia   Bolívar
# 4            5/Enero/2006           El Trapiche    Antioquia   Bolívar
# ...                   ...                   ...          ...       ...
# 489617  27/Diciembre/2018   Manuel M. Mallarino        Valle  Trujillo
# 489618  28/Diciembre/2018   Manuel M. Mallarino        Valle  Trujillo
# 489619  29/Diciembre/2018   Manuel M. Mallarino        Valle  Trujillo
# 489620  30/Diciembre/2018   Manuel M. Mallarino        Valle  Trujillo
# 489621  31/Diciembre/2018   Manuel M. Mallarino        Valle  Trujillo
#
#         Temperatura_min  Temperatura_max  Temperatura_med  Humedad_rel  \
# ...
